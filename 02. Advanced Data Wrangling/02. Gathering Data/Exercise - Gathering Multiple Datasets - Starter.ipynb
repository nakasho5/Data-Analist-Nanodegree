# %% [markdown]
# # Exercise - Gathering Multiple Datasets
#
# In this excersise, you will gather the hospital building data using three different gathering methods. The data includes information on hospital buildings such as height, number of stories, etc.
#
# Ensure you programmatically load your dataset(s) into the notebook.

# %%
#Imports - can be modified
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %% [markdown]
# ## 1. Extract a dataset via API

# %% [markdown]
# ### 1.1 Extract a dataset via API
# You may use the requests library to do so programmatically, or manually access the dataset via an API:
#
# https://data.chhs.ca.gov/api/3/action/datastore_search?resource_id=d97adf28-ebaf-4204-a29e-bb6bdb7f96b9

# %%
#FILL IN
#Exteact data via API
url = 'https://data.chhs.ca.gov/api/3/action/datastore_search?resource_id=d97adf28-ebaf-4204-a29e-bb6bdb7f96b9'
api_metadata = requests.get(url)

#Raise an exception if we made a request resulting in an error
api_metadata.raise_for_status()

#Get the JSON
api_text = api_metadata.json()
print(api_text)
# Out:
# {'help': 'https://data.chhs.ca.gov/api/3/action/help_show?name=datastore_search', 'success': True, 'result': {'include_total': True, 'resource_id': 'd97adf28-ebaf-4204-a29e-bb6bdb7f96b9', 'fields': [{'type': 'int', 'id': '_id'}, {'type': 'text', 'id': 'County Code'}, {'type': 'text', 'id': 'Perm ID'}, {'type': 'text', 'id': 'Facility Name'}, {'type': 'text', 'id': 'City'}, {'type': 'text', 'id': 'Building Nbr'}, {'type': 'text', 'id': 'Building Name'}, {'type': 'text', 'id': 'Building Status'}, {'type': 'text', 'id': 'SPC Rating *'}, {'type': 'text', 'id': 'Building URL'}, {'type': 'text', 'id': 'Height (ft)'}, {'type': 'text', 'id': 'Stories'}, {'type': 'text', 'id': 'Building Code'}, {'type': 'text', 'id': 'Building Code Year'}, {'type': 'text', 'id': 'Year Completed'}, {'type': 'text', 'id': 'AB 1882 Notice'}, {'type': 'text', 'id': 'Latitude'}, {'type': 'text', 'id': 'Longitude'}, {'type': 'text', 'id': 'Count'}], 'records_format': 'objects', 'records': [{'Count': '1', 'Facility Name': 'Alameda Hospital', 'County Code': '01 - Alameda', 'Height (ft)': '44.17', 'Building Code Year': None, 'City': 'Alameda', 'Building Code': 'Unknown', 'Building Nbr': 'BLD-01278', 'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=26HIS&capID2=00000&capID3=00002&agencyCode=OSHPD', 'Year Completed': '1926', 'Building Status': 'No Gen Acute Care - OSHPD Bldg', 'SPC Rating *': 'N/A', 'Building Name': 'Original Hospital', 'Longitude': '-122.2538986', 'Latitude': '37.7626572', 'Stories': '4', 'Perm ID': '11210', '_id': 1, 'AB 1882 Notice': None}, {'Count': '1', 'Facility Name': 'Alameda Hospital', 'County Code': '01 - Alameda', 'Height (ft)': '35', 'Building Code Year': '1952', 'City': 'Alameda', 'Building Code': '1952 Uniform Building Code (UBC)', 'Building Nbr': 'BLD-01279', 'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=56HIS&capID2=00000&capID3=00012&agencyCode=OSHPD', 'Year Completed': '1956', 'Building Status': 'In Service', 'SPC Rating *': '2', 'Building Name': 'Stephens Wing', 'Longitude': '-122.2538986', 'Latitude': '37.7626572', 'Stories': '3', 'Perm ID': '11210', '_id': 2, 'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.'}, {'Count': '1', 'Facility Name': 'Alameda Hospital', 'County Code': '01 - Alameda', 'Height (ft)': None, 'Building Code Year': '1964', 'City': 'Alameda', 'Building Code': '1964 Uniform Building Code (UBC)', 'Building Nbr': 'BLD-01280', 'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=68HIS&capID2=00000&capID3=00036&agencyCode=OSHPD', 'Year Completed': '1968', 'Building Status': 'In Service', 'SPC Rating *': '2', 'Building Name': 'West Wing', 'Longitude': '-122.2538986', 'Latitude': '37.7626572', 'Stories': '2', 'Perm ID': '11210', '_id': 3, 'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.'}, {'Count': '1', 'Facility Name': 'Alameda Hospital', 'County Code': '01 - Alameda', 'Height (ft)': None, 'Building Code Year': '1976', 'City': 'Alameda', 'Building Code': '1976 California Building Code (CBC)', 'Building Nbr': 'BLD-01281', 'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=83HIS&capID2=00000&capID3=00027&agencyCode=OSHPD', 'Year Completed': '1983', 'Building Status': 'In Service', 'SPC Rating *': '3s', 'Building Name': 'South Wing', 'Longitude': '-122.2538986', 'Latitude': '37.7626572', 'Stories': '3', 'Perm ID': '11210', '_id': 4, 'AB 1882 Notice': None}, {'Count': '1', 'Facility Name': 'Alameda Hospital', 'County Code': '01 - Alameda', 'Height (ft)': '27', 'Building Code Year': '1985', 'City': 'Alameda', 'Building Code': '1985 California Building Code (CBC)', 'Building Nbr': 'BLD-01282', 'B ...

# %% [markdown]
# ### 1.2 Parse the obtained data
# Parse the obtained data to get the **first** relevant data value or record from your JSON file.
#
# **Note:** Please ensure the result you obtain is in text and is relevant to hospital building data.

# %%
#Fill in - get the first data record/value from the JSON results
api_text['result']['records'][0]
# Out:
# {'Count': '1',
#  'Facility Name': 'Alameda Hospital',
#  'County Code': '01 - Alameda',
#  'Height (ft)': '44.17',
#  'Building Code Year': None,
#  'City': 'Alameda',
#  'Building Code': 'Unknown',
#  'Building Nbr': 'BLD-01278',
#  'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=26HIS&capID2=00000&capID3=00002&agencyCode=OSHPD',
#  'Year Completed': '1926',
#  'Building Status': 'No Gen Acute Care - OSHPD Bldg',
#  'SPC Rating *': 'N/A',
#  'Building Name': 'Original Hospital',
#  'Longitude': '-122.2538986',
#  'Latitude': '37.7626572',
#  'Stories': '4',
#  'Perm ID': '11210',
#  '_id': 1,
#  'AB 1882 Notice': None}

# %% [markdown]
# *Fill in*: What data did you see in the output value?
# Answer:
# I see data related to a hospital building in Alemeda. The facility name is Alameda Hospital and the building has four stories. The buildging Nbr is `BLD-01278`.

# %% [markdown]
# ## 2. Extract a dataset via manual download

# %% [markdown]
# ### 2.1 Download a dataset manually
# We provided you a csv file `hospital_building_data.csv`. You can think that we pre-downlowed the data for you.
#
# Load the dataset into this notebook.

# %%
#FILL IN - load a dataset that was downloaded manually into a dataframe
cal_hhs = pd.read_csv('hospital_building_data.csv', encoding='utf-8')

# %% [markdown]
# ### 2.2 Parse the obtained data
# Parse the obtained data to get the **first** relevant data value or record from your manually downloaded dataset.
#
# **Note:** Please ensure the result you obtain is relevant to the hostiple building data.

# %%
#Fill in - get the first data record/value from the manually downloaded file
cal_hhs.head(1)
# Out:
#     County Code  Perm ID     Facility Name     City Building Nbr  \
# 0  01 - Alameda    11210  Alameda Hospital  Alameda    BLD-01278
#
#        Building Name                 Building Status SPC Rating *  \
# 0  Original Hospital  No Gen Acute Care - OSHPD Bldg          NaN
#
#                                         Building URL  Height (ft)  Stories  \
# 0  https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...        44.17      4.0
#
#   Building Code  Building Code Year  Year Completed AB 1882 Notice   Latitude  \
# 0       Unknown                 NaN          1926.0            NaN  37.762657
#
#     Longitude  Count
# 0 -122.253899      1

# %% [markdown]
# *Fill in*: What data did you see in the output? Is that the same with the data you gathered from the API?

# %% [markdown]
# ## 3. Extract a dataset via scraping

# %% [markdown]
# ### 3.1 Extract your dataset via scraping
# Data webpage url:
#
# https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9
#
# Extract your dataset via scraping using `requests`, and `BeautifulSoup`.

# %%
##FILL IN 
#Extract a dataset via scraping
url = 'https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9'
data = requests.get(url)

#Raise an exception if we made a request resulting in an error
data.raise_for_status()

#Access the content of the response in Unicode
data_txt = data.text
print(data_txt)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="yes"?>
# <feed xml:base="https://data.chhs.ca.gov/datastore/odata3.0/" xmlns:d="http://schemas.microsoft.com/ado/2007/08/dataservices" xmlns:m="http://schemas.microsoft.com/ado/2007/08/dataservices/metadata" xmlns="http://www.w3.org/2005/Atom">
#   <title type="text">Hospital Building Data (CSV)</title>
#   <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9</id>
#   <updated>2023-06-16T20:58:49.601875Z</updated>
#   <link rel="self" title="d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" href="https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" />
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(1)</id>
#     <title type="text">Row 1</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">1</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-01278</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Original Hospital</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">No Gen Acute Care - OSHPD Bldg</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">N/A</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=26HIS&amp;capID2=00000&amp;capID3=00002&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">44.17</d:Heightft>
#
#         <d:Stories m:type="Edm.String">4</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">Unknown</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String" m:null="true" />
#
#         <d:YearCompleted m:type="Edm.String">1926</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(2)</id>
#     <title type="text">Row 2</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">2</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-01279</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Stephens Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=56HIS&amp;capID2=00000&amp;capID3=00012&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">35</d:Heightft>
#
#         <d:Stories m:type="Edm.String">3</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1952 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1952</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1956</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(3)</id>
#     <title type="text">Row 3</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">3</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-01280</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">West Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=68HIS&amp;capID2=00000&amp;capID3=00036&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">2</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1964 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1964</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1968</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(4)</id>
#     <title type="text">Row 4</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">4</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-01281</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">South Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">3s</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=83HIS&amp;capID2=00000&amp;capID3=00027&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">3</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1976 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1976</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1983</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(5)</id>
#     <title type="text">Row 5</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">5</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-01282</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Radiology Addition</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">4</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=95HIS&amp;capID2=00000&amp;capID3=00031&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">27</d:Heightft>
#
#         <d:Stories m:type="Edm.String">2</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1985 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1985</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1995</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(6)</id>
#     <title type="text">Row 6</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">6</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-01283</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Medical Gas Storage</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">3</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=95HIS&amp;capID2=00000&amp;capID3=00032&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">8.42</d:Heightft>
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1985 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1985</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1995</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(7)</id>
#     <title type="text">Row 7</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">7</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-02630</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Compactor Shed</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">4</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=83HIS&amp;capID2=00000&amp;capID3=00048&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1976 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1976</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1983</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(8)</id>
#     <title type="text">Row 8</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">8</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-03120</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Emergency Room Relocation</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">3s</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=87HIS&amp;capID2=00000&amp;capID3=00045&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1979 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1979</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1988</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(9)</id>
#     <title type="text">Row 9</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">9</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11210</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alameda Hospital</d:FacilityName>
#
#         <d:City m:type="Edm.String">Alameda</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-05597</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">LOX Tank</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">Under Construction</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">N/A</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=13CAP&amp;capID2=00000&amp;capID3=003TM&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String" m:null="true" />
#
#         <d:BuildingCode m:type="Edm.String">2010 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">2010</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">2016</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.7626572</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2538986</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(10)</id>
#     <title type="text">Row 10</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">10</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00695</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Ehman Building</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=37HIS&amp;capID2=00000&amp;capID3=00001&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">49.75</d:Heightft>
#
#         <d:Stories m:type="Edm.String">4</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1927 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1927</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1937</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(11)</id>
#     <title type="text">Row 11</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">11</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00696</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">North Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=52HIS&amp;capID2=00000&amp;capID3=00004&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">50</d:Heightft>
#
#         <d:Stories m:type="Edm.String">4</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1946 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1946</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1952</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(12)</id>
#     <title type="text">Row 12</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">12</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00698</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">East Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=64HIS&amp;capID2=00000&amp;capID3=00015&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">62.5</d:Heightft>
#
#         <d:Stories m:type="Edm.String">5</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1961 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1961</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1964</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(13)</id>
#     <title type="text">Row 13</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">13</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00699</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Original West Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=45HIS&amp;capID2=00000&amp;capID3=00001&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">36</d:Heightft>
#
#         <d:Stories m:type="Edm.String">3</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1943 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1943</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1945</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(14)</id>
#     <title type="text">Row 14</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">14</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00700</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">West Service Wing - Building 1</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=64HIS&amp;capID2=00000&amp;capID3=00016&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">33.3</d:Heightft>
#
#         <d:Stories m:type="Edm.String">3</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1961 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1961</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1965</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(15)</id>
#     <title type="text">Row 15</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">15</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00701</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Physio-Therapy Building</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=60HIS&amp;capID2=00000&amp;capID3=00012&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">12</d:Heightft>
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1952 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1952</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1960</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(16)</id>
#     <title type="text">Row 16</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">16</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00702</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Original Emergency Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=60HIS&amp;capID2=00000&amp;capID3=00013&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">12</d:Heightft>
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1952 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1952</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1960</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(17)</id>
#     <title type="text">Row 17</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">17</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00703</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Special Procedures Addition</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">3</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=74HIS&amp;capID2=00000&amp;capID3=00012&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1973 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1973</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1974</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(18)</id>
#     <title type="text">Row 18</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">18</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00704</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Emergency Department Expansion</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">5s</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=01HIS&amp;capID2=00000&amp;capID3=00013&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1995 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1995</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">2002</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(19)</id>
#     <title type="text">Row 19</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">19</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00705</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Cogeneration Building</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">4</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=90HIS&amp;capID2=00000&amp;capID3=00024&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">11.75</d:Heightft>
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1982 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1982</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1990</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(20)</id>
#     <title type="text">Row 20</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">20</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00706</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Emergency Generator Building</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">4</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=80HIS&amp;capID2=00000&amp;capID3=00499&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">2</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1973 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1973</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1982</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(21)</id>
#     <title type="text">Row 21</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">21</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00707</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Transformer Building</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=69HIS&amp;capID2=00000&amp;capID3=00013&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">21.7</d:Heightft>
#
#         <d:Stories m:type="Edm.String">2</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1967 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1967</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1969</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(22)</id>
#     <title type="text">Row 22</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">22</d:_id>
#
#         <d:CountyCode m:type="Edm.String">01 - Alameda</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">11322</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Alta Bates Summit Medical Center</d:FacilityName>
#
#         <d:City m:type="Edm.String">Oakland</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-03431</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">South Wing - Phase 2</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">3</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=78HIS&amp;capID2=00000&amp;capID3=00055&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">102.5</d:Heightft>
#
#         <d:Stories m:type="Edm.String">6</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1973 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1973</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1980</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">37.8208094</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-122.2630806</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(23)</id>
#     <title type="text">Row 23</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
# ...
#
#         <d:Heightft m:type="Edm.String">26</d:Heightft>
#
#         <d:Stories m:type="Edm.String">2</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1946 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1946</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1949</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(494)</id>
#     <title type="text">Row 494</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">494</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00766</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Original Power Plant</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=49HIS&amp;capID2=00000&amp;capID3=00008&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">15</d:Heightft>
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1946 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1946</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1949</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(495)</id>
#     <title type="text">Row 495</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">495</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00767</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Administration Wing</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">2</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=69HIS&amp;capID2=00000&amp;capID3=00014&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String">14</d:Heightft>
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1967 Uniform Building Code (UBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1967</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1969</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String">This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.</d:AB1882Notice>
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(496)</id>
#     <title type="text">Row 496</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">496</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00768</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">ICU Addition</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">4</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=85HIS&amp;capID2=00000&amp;capID3=00010&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1979 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1979</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1987</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(497)</id>
#     <title type="text">Row 497</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">497</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00769</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Outpatient Addition</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">4</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=89HIS&amp;capID2=00000&amp;capID3=00014&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1979 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1979</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">1992</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(498)</id>
#     <title type="text">Row 498</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">498</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00770</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">Women&#39;s Center</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">5</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=00HIS&amp;capID2=00000&amp;capID3=00044&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">2</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1989 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1989</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">2000</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(499)</id>
#     <title type="text">Row 499</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">499</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00771</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">ER</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">5</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=00HIS&amp;capID2=00000&amp;capID3=00045&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1989 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1989</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">2000</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#   <entry>
#     <id>https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(500)</id>
#     <title type="text">Row 500</title>
#     <updated>2023-06-16T20:58:49.601875Z</updated>
#     <author>
#       <name>ckan</name>
#     </author>
#     <category term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" />
#     <content type="application/xml">
#       <m:properties>
#
#         <d:_id m:type="Edm.String">500</d:_id>
#
#         <d:CountyCode m:type="Edm.String">13 - Imperial</d:CountyCode>
#
#         <d:PermID m:type="Edm.String">10192</d:PermID>
#
#         <d:FacilityName m:type="Edm.String">Pioneers Memorial Healthcare District</d:FacilityName>
#
#         <d:City m:type="Edm.String">Brawley</d:City>
#
#         <d:BuildingNbr m:type="Edm.String">BLD-00772</d:BuildingNbr>
#
#         <d:BuildingName m:type="Edm.String">New Power Plant</d:BuildingName>
#
#         <d:BuildingStatus m:type="Edm.String">In Service</d:BuildingStatus>
#
#         <d:SPCRating m:type="Edm.String">5</d:SPCRating>
#
#         <d:BuildingURL m:type="Edm.String">https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=00HIS&amp;capID2=00000&amp;capID3=00046&amp;agencyCode=OSHPD</d:BuildingURL>
#
#         <d:Heightft m:type="Edm.String" m:null="true" />
#
#         <d:Stories m:type="Edm.String">1</d:Stories>
#
#         <d:BuildingCode m:type="Edm.String">1989 California Building Code (CBC)</d:BuildingCode>
#
#         <d:BuildingCodeYear m:type="Edm.String">1989</d:BuildingCodeYear>
#
#         <d:YearCompleted m:type="Edm.String">2000</d:YearCompleted>
#
#         <d:AB1882Notice m:type="Edm.String" m:null="true" />
#
#         <d:Latitude m:type="Edm.String">32.9581223</d:Latitude>
#
#         <d:Longitude m:type="Edm.String">-115.5538635</d:Longitude>
#
#         <d:Count m:type="Edm.String">1</d:Count>
#
#       </m:properties>
#     </content>
#   </entry>
#
#
#   <link rel="next" href="https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9?$skip=500&amp;$top=500" />
#
# </feed>

# %%
#FILL IN
# Use BeautifulSoup to parse the result
soup_text = BeautifulSoup(data_txt)

# Print the prettified version
soup_text.prettify()

# %% [markdown]
# ### 3.2 Parse the obtained data
# **Note:** Please ensure the result you obtain is in text (not with HTML tags) and is relevant to the hospital buidling data. Hint: you can use the `find_all()` methood with tags like `d:buildingname`, `d:buildingcode`, etc.

# %%
#FILL IN - parse specific records from scraped data
[hs.get_text() for hs in soup_text.find_all('d:buildingname')]

# %% [markdown]
# *FILL IN*: Brief description of specific data parsed.
# Answer:
# I parsed all the hospital building in the dataset.
